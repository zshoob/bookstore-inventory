# %%
import requests
from urllib import urlencode
from datetime import datetime
import hashlib
import hmac
import base64
import pytz
import xmltodict
import pandas as pd
from main.common import *
from numpy import atleast_1d

def traverse(xml, path, default=''):
    for node in path.split('/'):
        try:
            node = int(node)
        except ValueError:
            pass
        try:
            xml = xml[node]
        except (KeyError, TypeError):
            return default
    return xml

class AmazonEndpoint:
    api = 'Products'
    universal_params = {
        'AWSAccessKeyId': 'AKIAIR3XDAZOXFNE2WMA',
        'SellerId': 'A2QZBXE6ZQI12C',
        'MarketplaceId': 'ATVPDKIKX0DER',
        'Version': '2011-10-01',
        'SignatureMethod': 'HmacSHA256',
        'SignatureVersion': '2',
    }
    secret_key = bytes('zvqE0L6YkYfE1kpcaD6OIIDaX9Ttc1awIUrv7yoM').encode('utf-8')

    def get_params(self, *args):
        raise Exception

    def read(self, response):
        raise Exception

    def get(self, *args):
        params = self.get_params(*args)
        params['Timestamp'] = datetime.isoformat(datetime.now(pytz.timezone('US/Eastern')))
        params_str = '&'.join([urlencode({k:params[k]}) for k in sorted(params)])
        request = 'POST\nmws.amazonservices.com\n/%s/\n%s' % (self.api, params_str)
        message = bytes(request).encode('utf-8')
        params['Signature'] = base64.b64encode(hmac.new(self.secret_key, message, digestmod=hashlib.sha256).digest())
        response = requests.post('https://mws.amazonservices.com/%s/' % self.api, data=params)
        return response

    def fetch(self, *args):
        return self.read(self.get(*args))

class ProductFundamentals(AmazonEndpoint):
    action = 'GetMatchingProductForId'

    def get_params(self, isbns):
        params = self.universal_params.copy()
        params['Action'] = self.action
        params['IdType'] = 'ASIN'
        for ix, isbn in enumerate(atleast_1d(isbns)):
            params['IdList.Id.%s' % str(ix+1)] = isbn
        return params

    def read_product(self, product):
        asin = traverse(product, 'Identifiers/MarketplaceASIN/ASIN')
        attributes = traverse(product, 'AttributeSets/ns2:ItemAttributes')
        authors = atleast_1d(traverse(attributes, 'ns2:Author'))
        height, length, width, weight = [traverse(attributes, 'ns2:ItemDimensions/ns2:%s' % key) for key in ['Height','Length','Width','Weight']]
        height, length, width, weight = ['%s %s' % (traverse(dim,'#text'), traverse(dim,'@Units')) if dim else '' for dim in [height, length, width, weight]]
        languages = atleast_1d(traverse(attributes, 'ns2:Languages/ns2:Language'))
        language = [l['ns2:Name'] for l in languages if traverse(l,'ns2:Type') == 'Published']
        if language:
            language = language[0]
        list_price = traverse(attributes, 'ns2:ListPrice/ns2:Amount')
        flats = ['ns2:NumberOfPages', 'ns2:PublicationDate', 'ns2:Publisher', 'ns2:ReleaseDate', 'ns2:Title', 'ns2:Binding', 'ns2:Edition']
        pages, published, publisher, released, title, binding, edition = [traverse(attributes, path) for path in flats]
        sales_rank = traverse(product, 'SalesRankings/SalesRank')
        if sales_rank:
            sales_rank = atleast_1d(sales_rank)
        else:
            sales_rank = []
        image_source = traverse(attributes, 'ns2:SmallImage/ns2:URL')
        resized = re.sub('\._.*\.jpg','._SX331_BO1,204,203,200_.jpg',image_source)
        data = dict(
            asin=asin,
            authors=authors,
            height=height,
            length=length,
            width=width,
            weight=weight,
            language=language,
            list_price=list_price,
            pages=pages,
            published=published,
            released=released,
            publisher=publisher,
            title=title,
            binding=binding,
            edition=edition,
            sales_rank=sales_rank,
            image_source=resized
        )
        return data

    def read(self, response, raw=False):
        xml = xmltodict.parse(response.text)
        xml = traverse(xml, '%sResponse/%sResult' % (self.action, self.action))
        status = traverse(xml, '@status')
        error = traverse(xml, 'Error/Message')
        if error:
            return [dict(last_status=status, error=error)]
        if raw:
            return atleast_1d(traverse(xml, 'Products/Product'))
        return [self.read_product(product) for product in atleast_1d(traverse(xml, 'Products/Product'))]

class LowestPricedOffers(AmazonEndpoint):
    def get_params(self, asin, condition):
        params = self.universal_params.copy()
        params['Action'] = 'GetLowestPricedOffersForASIN'
        params['ASIN'] = asin
        params['ItemCondition'] = condition
        return params

    def read_offer(self, xml):
        offer = xml.copy()
        if 'ShipsFromCountry' in offer.keys(): # already flattened
            offer['ShipsFromCountry'] = offer['ShipsFromCountry'] or ''
            return offer

        feedback = offer.pop('SellerFeedbackRating')
        offer['SellerFeedbackRating'] = feedback[u'SellerPositiveFeedbackRating']
        offer['FeedbackCount'] = feedback['FeedbackCount']
        price = offer.pop('ListingPrice')
        offer['Price'] = price['Amount']
        shipping_price = offer.pop('Shipping')
        offer['ShippingPrice'] = shipping_price['Amount']
        shipping_time = offer.pop('ShippingTime')
        offer['ShippingMinimumHours'] = shipping_time['@minimumHours']
        offer['ShippingMaximumHours'] = shipping_time['@maximumHours']
        offer['ShippingAvailability'] = shipping_time['@availabilityType']
        ships_from = offer.pop('ShipsFrom', {})
        offer['ShipsFromCountry'] = traverse(ships_from, 'Country') or ''
        offer['ShipsFromState'] = traverse(ships_from, 'State')

        return offer

    def read_summary(self, xml):
        summary = traverse(xml, 'Summary') or xml
        list_price = traverse(summary, 'ListPrice/Amount')
        total_offer_count = traverse(summary, 'TotalOfferCount')

        number_of_offers = pd.DataFrame(traverse(summary, 'NumberOfOffers/OfferCount'))
        number_of_offers.rename(columns={
            '#text': 'NumberOfOffers',
            '@condition': 'Condition',
            '@fulfillmentChannel': 'FulfillmentChannel'
        }, inplace=True)
        number_of_offers = number_of_offers.to_dict(orient='records')

        lowest_prices = pd.DataFrame(traverse(summary, 'LowestPrices/LowestPrice'))
        lowest_prices.rename(columns={
            '@condition': 'Condition',
            '@fulfillmentChannel': 'FulfillmentChannel'
        }, inplace=True)
        lowest_prices[['LandedPrice','ListingPrice','Shipping']] = lowest_prices[['LandedPrice','ListingPrice','Shipping']].applymap(lambda d: d['Amount'])
        lowest_prices = lowest_prices.to_dict(orient='records')

        buybox_prices = pd.DataFrame(traverse(summary, 'BuyBoxPrices/BuyBoxPrice'))
        buybox_prices.rename(columns={'@condition':'Condition'}, inplace=True)
        buybox_prices[['LandedPrice','ListingPrice','Shipping']] = buybox_prices[['LandedPrice','ListingPrice','Shipping']].applymap(lambda d: d['Amount'])
        buybox_prices = buybox_prices.to_dict(orient='records')

        buybox_eligible_offers = pd.DataFrame(traverse(summary, 'BuyBoxEligibleOffers/OfferCount'))
        buybox_eligible_offers.rename(columns={
            '#text': 'NumberOfOffers',
            '@condition': 'Condition',
            '@fulfillmentChannel': 'FulfillmentChannel'
        }, inplace=True)
        buybox_eligible_offers = buybox_eligible_offers.to_dict(orient='records')

        data = dict(
            list_price=list_price,
            total_offer_count=total_offer_count,
            number_of_offers=number_of_offers,
            lowest_prices=lowest_prices,
            buybox_prices=buybox_prices,
            buybox_eligible_offers=buybox_eligible_offers
        )

        return data

    def read(self, response, raw=False):
        xml = xmltodict.parse(response.text)
        xml = traverse(xml, 'GetLowestPricedOffersForASINResponse/GetLowestPricedOffersForASINResult')
        offers = atleast_1d(traverse(xml, 'Offers/Offer'))
        if not raw:
            offers = [self.read_offer(o) for o in offers]
        summary = traverse(xml, 'Summary')
        if not raw:
            summary = self.read_summary(summary)
        return dict(offers=offers, summary=summary)

class ProductCategories(AmazonEndpoint):
    def get_params(self, asin):
        params = self.universal_params.copy()
        params['Action'] = 'GetProductCategoriesForASIN'
        params['ASIN'] = asin
        return params

class ProductsForQuery(ProductFundamentals):
    action = 'ListMatchingProducts'
    def get_params(self, query):
        params = self.universal_params.copy()
        params['Action'] = 'ListMatchingProducts'
        params['QueryContextId'] = 'Books'
        params['Query'] = query
        return params
    
clrs = '0262033844'
three_body = '0765382032'
gott = '1594634025'
foundation = '0553293354'

# %%
response = ProductsForQuery().get('insurgent')

# %%
raw = ProductsForQuery().read(response, raw=True)

# %%
product = ProductsForQuery().read(response)[0]

# %%
response.text
# Out:
# u'<?xml version="1.0"?>\n<ListMatchingProductsResponse xmlns="http://mws.amazonservices.com/schema/Products/2011-10-01"><ListMatchingProductsResult><Products xmlns="http://mws.amazonservices.com/schema/Products/2011-10-01" xmlns:ns2="http://mws.amazonservices.com/schema/Products/2011-10-01/default.xsd"><Product><Identifiers><MarketplaceASIN><MarketplaceId>ATVPDKIKX0DER</MarketplaceId><ASIN>0062024051</ASIN></MarketplaceASIN></Identifiers><AttributeSets><ns2:ItemAttributes xml:lang="en-US"><ns2:Author>Roth, Veronica</ns2:Author><ns2:Binding>Paperback</ns2:Binding><ns2:Edition>Reissue</ns2:Edition><ns2:ItemDimensions><ns2:Height Units="inches">8.00</ns2:Height><ns2:Length Units="inches">5.31</ns2:Length><ns2:Width Units="inches">1.33</ns2:Width><ns2:Weight Units="pounds">0.65</ns2:Weight></ns2:ItemDimensions><ns2:IsAdultProduct>false</ns2:IsAdultProduct><ns2:Label>Katherine Tegen Books</ns2:Label><ns2:Languages><ns2:Language><ns2:Name>english</ns2:Name><ns2:Type>Published</ns2:Type></ns2:Language><ns2:Language><ns2:Name>english</ns2:Name><ns2:Type>Original Language</ns2:Type></ns2:Language><ns2:Language><ns2:Name>english</ns2:Name><ns2:Type>Unknown</ns2:Type></ns2:Language></ns2:Languages><ns2:ListPrice><ns2:Amount>12.99</ns2:Amount><ns2:CurrencyCode>USD</ns2:CurrencyCode></ns2:ListPrice><ns2:Manufacturer>Katherine Tegen Books</ns2:Manufacturer><ns2:NumberOfItems>1</ns2:NumberOfItems><ns2:NumberOfPages>592</ns2:NumberOfPages><ns2:PackageDimensions><ns2:Height Units="inches">1.60</ns2:Height><ns2:Length Units="inches">8.00</ns2:Length><ns2:Width Units="inches">5.25</ns2:Width><ns2:Weight Units="pounds">0.95</ns2:Weight></ns2:PackageDimensions><ns2:PackageQuantity>1</ns2:PackageQuantity><ns2:ProductGroup>Book</ns2:ProductGroup><ns2:ProductTypeName>ABIS_BOOK</ns2:ProductTypeName><ns2:PublicationDate>2015-01-20</ns2:PublicationDate><ns2:Publisher>Katherine Tegen Books</ns2:Publisher><ns2:ReleaseDate>2015-01-20</ns2:ReleaseDate><ns2:SmallImage><ns2:URL>http://ecx.images-amazon.com/images/I/51YMf0SVDaL._SL75_.jpg</ns2:URL><ns2:Height Units="pixels">75</ns2:Height><ns2:Width Units="pixels">50</ns2:Width></ns2:SmallImage><ns2:Studio>Katherine Tegen Books</ns2:Studio><ns2:Title>Insurgent (Divergent Series)</ns2:Title></ns2:ItemAttributes></AttributeSets><Relationships/><SalesRankings><SalesRank><ProductCategoryId>book_display_on_website</ProductCategoryId><Rank>2978</Rank></SalesRank><SalesRank><ProductCategoryId>10368581011</ProductCategoryId><Rank>10</Rank></SalesRank><SalesRank><ProductCategoryId>7538399011</ProductCategoryId><Rank>54</Rank></SalesRank><SalesRank><ProductCategoryId>10368622011</ProductCategoryId><Rank>56</Rank></SalesRank></SalesRankings></Product><Product><Identifiers><MarketplaceASIN><MarketplaceId>ATVPDKIKX0DER</MarketplaceId><ASIN>0062421379</ASIN></MarketplaceASIN></Identifiers><AttributeSets><ns2:ItemAttributes xml:lang="en-US"><ns2:Author>Roth, Veronica</ns2:Author><ns2:Binding>Paperback</ns2:Binding><ns2:Edition>Box</ns2:Edition><ns2:ItemDimensions><ns2:Height Units="inches">8.00</ns2:Height><ns2:Length Units="inches">5.50</ns2:Length><ns2:Width Units="inches">5.25</ns2:Width><ns2:Weight Units="pounds">0.65</ns2:Weight></ns2:ItemDimensions><ns2:Label>Katherine Tegen Books</ns2:Label><ns2:Languages><ns2:Language><ns2:Name>english</ns2:Name><ns2:Type>Published</ns2:Type></ns2:Language><ns2:Language><ns2:Name>english</ns2:Name><ns2:Type>Original Language</ns2:Type></ns2:Language><ns2:Language><ns2:Name>english</ns2:Name><ns2:Type>Unknown</ns2:Type></ns2:Language></ns2:Languages><ns2:ListPrice><ns2:Amount>51.96</ns2:Amount><ns2:CurrencyCode>USD</ns2:CurrencyCode></ns2:ListPrice><ns2:Manufacturer>Katherine Tegen Books</ns2:Manufacturer><ns2:NumberOfItems>4</ns2:NumberOfItems><ns2:NumberOfPages>2064</ns2:NumberOfPages><ns2:PackageDimensions><ns2:Height Units="inches">5.12</ns2:Height><ns2:Length Units="inches">8.43</ns2:Length><ns2:Width Units="inches">5.75</ns2:Width><ns2:Weight Units="pounds">3.31</ns2:Weight></ns ...

# %%
rank_item = product.get('sales_rank')[0]

# %%
rank_item.get('ProductCategoryId')
# Out:
# u'book_display_on_website'

# %%
ProductFundamentals().fetch('B00LA14KWC')
# Out:
# [{'error': u'Invalid ISBN identifier B00LA14KWC for marketplace ATVPDKIKX0DER',
#   'last_status': u'ClientError'}]

# %%
response = products_for_query.get("harry potter dvd")

# %%
xml = xmltodict.parse(response.text)

# %%
xml
# Out:
# OrderedDict([(u'ErrorResponse',
#               OrderedDict([(u'@xmlns',
#                             u'http://mws.amazonservices.com/schema/Products/2011-10-01'),
#                            (u'Error',
#                             OrderedDict([(u'Type', u'Sender'),
#                                          (u'Code', u'SignatureDoesNotMatch'),
#                                          (u'Message',
#                                           u'The request signature we calculated does not match the signature you provided. Check your AWS Secret Access Key and signing method. Consult the service documentation for details.')])),
#                            (u'RequestID',
#                             u'996ea6cd-2d2f-4706-b6e5-e88117eaf06d')]))])

# %%
products_for_query.read(response)
# Out:
# [{'asin': u'0262033844',
#   'authors': array([u'Cormen, Thomas H.', u'Leiserson, Charles E.',
#          u'Rivest, Ronald L.', u'Stein, Clifford'],
#         dtype='<U21'),
#   'binding': u'Hardcover',
#   'edition': u'3rd',
#   'height': u'9.00 inches',
#   'image_source': u'http://ecx.images-amazon.com/images/I/41-1VkO%2B1lL._SX331_BO1,204,203,200_.jpg',
#   'language': u'english',
#   'length': u'8.00 inches',
#   'list_price': u'99.00',
#   'pages': u'1312',
#   'published': u'2009-07-31',
#   'publisher': u'The MIT Press',
#   'released': '',
#   'sales_rank': [OrderedDict([(u'ProductCategoryId',
#                  u'book_display_on_website'),
#                 (u'Rank', u'3244')]),
#    OrderedDict([(u'ProductCategoryId', u'491298'), (u'Rank', u'1')]),
#    OrderedDict([(u'ProductCategoryId', u'132570011'), (u'Rank', u'2')]),
#    OrderedDict([(u'ProductCategoryId', u'3508'), (u'Rank', u'14')])],
#   'title': u'Introduction to Algorithms, 3rd Edition (MIT Press)',
#   'weight': u'4.85 pounds',
#   'width': u'1.75 inches'},
#  {'asin': u'B007YXXTRM', 'authors': array([u'Charles E. Leiserson'],
#         dtype='<U20'), 'binding': u'Paperback', 'edition': u'Cincias Exatas', 'height': '', 'image_source': u'http://ecx.images-amazon.com/images/I/219KuzipKXL._SX331_BO1,204,203,200_.jpg', 'language': u'english', 'length': '', 'list_price': '', 'pages': '', 'published': u'2009-01-01', 'publisher': u'THE MIT PRESS', 'released': '', 'sales_rank': '', 'title': u'Introduction To Algorithms', 'weight': '', 'width': ''}]

# %%
def foo(bar=True):
    return bar

# %%
foo.func_name
# Out:
# 'foo'

# %%
d = ProductFundamentals().fetch(foundation)

# %%
d
# Out:
# [{'asin': u'0553293354', 'authors': array([u'Asimov, Isaac'],
#         dtype='<U13'), 'binding': u'Mass Market Paperback', 'edition': u'Revised', 'height': u'6.88 inches', 'image_source': u'http://ecx.images-amazon.com/images/I/51RZ30jFyDL._SX331_BO1,204,203,200_.jpg', 'language': u'english', 'length': u'4.17 inches', 'list_price': u'7.99', 'pages': u'296', 'published': u'1991-10-01', 'publisher': u'Bantam Spectra Books', 'released': u'1991-10-01', 'sales_rank': [OrderedDict([(u'ProductCategoryId',
#                  u'book_display_on_website'),
#                 (u'Rank', u'8045')]),
#    OrderedDict([(u'ProductCategoryId', u'16286'),
#                 (u'Rank',
#                  u'150')])], 'title': u'Foundation', 'weight': '', 'width': u'0.87 inches'},
#  {'asin': u'B007CJZEI0', 'authors': array([u'Asimov, Isaac'],
#         dtype='<U13'), 'binding': u'Paperback', 'edition': u'First Edition', 'height': '', 'image_source': u'http://ecx.images-amazon.com/images/I/51f-03Dqp2L._SX331_BO1,204,203,200_.jpg', 'language': u'english', 'length': '', 'list_price': '', 'pages': u'310', 'published': u'2004-01-01', 'publisher': u'Bantam Books', 'released': '', 'sales_rank': [OrderedDict([(u'ProductCategoryId',
#                  u'book_display_on_website'),
#                 (u'Rank', u'2541128')]),
#    OrderedDict([(u'ProductCategoryId', u'16286'),
#                 (u'Rank',
#                  u'5649')])], 'title': u'Foundation', 'weight': '', 'width': ''},
#  {'asin': u'B000FC1PWA', 'authors': array([u'Asimov, Isaac'],
#         dtype='<U13'), 'binding': u'Kindle Edition', 'edition': u'Revised', 'height': '', 'image_source': u'http://ecx.images-amazon.com/images/I/41toGX5Ub1L._SX331_BO1,204,203,200_.jpg', 'language': u'english', 'length': '', 'list_price': '', 'pages': u'320', 'published': u'2004-06-01', 'publisher': u'Spectra', 'released': u'2004-06-01', 'sales_rank': [OrderedDict([(u'ProductCategoryId',
#                  u'ebooks_display_on_website'),
#                 (u'Rank', u'6631')]),
#    OrderedDict([(u'ProductCategoryId', u'6809435011'), (u'Rank', u'13')]),
#    OrderedDict([(u'ProductCategoryId', u'6809440011'), (u'Rank', u'33')]),
#    OrderedDict([(u'ProductCategoryId', u'158595011'),
#                 (u'Rank',
#                  u'52')])], 'title': u'Foundation', 'weight': '', 'width': ''},
#  {'asin': u'B0073G4TH4', 'authors': array([u'ASIMOV, ISAAC'],
#         dtype='<U13'), 'binding': u'Paperback', 'edition': u'Revised', 'height': u'7.01 inches', 'image_source': u'http://ecx.images-amazon.com/images/I/31VgHSZqWCL._SX331_BO1,204,203,200_.jpg', 'language': u'english', 'length': u'0.83 inches', 'list_price': '', 'pages': '', 'published': u'2012-01-01', 'publisher': u'RANDOM HOU', 'released': '', 'sales_rank': [OrderedDict([(u'ProductCategoryId',
#                  u'book_display_on_website'),
#                 (u'Rank', u'7464355')]),
#    OrderedDict([(u'ProductCategoryId', u'271585011'), (u'Rank', u'23176')]),
#    OrderedDict([(u'ProductCategoryId', u'16273'), (u'Rank', u'52390')]),
#    OrderedDict([(u'ProductCategoryId', u'75'),
#                 (u'Rank',
#                  u'594096')])], 'title': u'Foundation', 'weight': u'0.34 pounds', 'width': u'4.25 inches'}]

# %%
r = ProductFundamentals().get(foundation)

# %%
raw = ProductFundamentals().read(r, raw=True)[0]

# %%
product = traverse(raw, 'Identifiers/MarketplaceASIN/ASIN')
attributes = traverse(raw, 'AttributeSets/ns2:ItemAttributes')

# %%
attributes
# Out:
# OrderedDict([(u'@xml:lang', u'en-US'),
#              (u'ns2:Author', u'Asimov, Isaac'),
#              (u'ns2:Binding', u'Mass Market Paperback'),
#              (u'ns2:Brand', u'Spectra'),
#              (u'ns2:Edition', u'Revised'),
#              (u'ns2:Feature', u'Used Book in Good Condition'),
#              (u'ns2:ItemDimensions',
#               OrderedDict([(u'ns2:Height',
#                             OrderedDict([(u'@Units', u'inches'),
#                                          ('#text', u'6.88')])),
#                            (u'ns2:Length',
#                             OrderedDict([(u'@Units', u'inches'),
#                                          ('#text', u'4.17')])),
#                            (u'ns2:Width',
#                             OrderedDict([(u'@Units', u'inches'),
#                                          ('#text', u'0.87')]))])),
#              (u'ns2:Label', u'Bantam Spectra Books'),
#              (u'ns2:Languages',
#               OrderedDict([(u'ns2:Language',
#                             [OrderedDict([(u'ns2:Name', u'english'),
#                                           (u'ns2:Type', u'Published')]),
#                              OrderedDict([(u'ns2:Name', u'english'),
#                                           (u'ns2:Type',
#                                            u'Original Language')]),
#                              OrderedDict([(u'ns2:Name', u'english'),
#                                           (u'ns2:Type', u'Unknown')])])])),
#              (u'ns2:ListPrice',
#               OrderedDict([(u'ns2:Amount', u'7.99'),
#                            (u'ns2:CurrencyCode', u'USD')])),
#              (u'ns2:Manufacturer', u'Bantam Spectra Books'),
#              (u'ns2:NumberOfItems', u'1'),
#              (u'ns2:NumberOfPages', u'296'),
#              (u'ns2:PackageDimensions',
#               OrderedDict([(u'ns2:Height',
#                             OrderedDict([(u'@Units', u'inches'),
#                                          ('#text', u'1.00')])),
#                            (u'ns2:Length',
#                             OrderedDict([(u'@Units', u'inches'),
#                                          ('#text', u'6.80')])),
#                            (u'ns2:Width',
#                             OrderedDict([(u'@Units', u'inches'),
#                                          ('#text', u'4.10')])),
#                            (u'ns2:Weight',
#                             OrderedDict([(u'@Units', u'pounds'),
#                                          ('#text', u'0.20')]))])),
#              (u'ns2:PackageQuantity', u'1'),
#              (u'ns2:ProductGroup', u'Book'),
#              (u'ns2:ProductTypeName', u'ABIS_BOOK'),
#              (u'ns2:PublicationDate', u'1991-10-01'),
#              (u'ns2:Publisher', u'Bantam Spectra Books'),
#              (u'ns2:ReleaseDate', u'1991-10-01'),
#              (u'ns2:SmallImage',
#               OrderedDict([(u'ns2:URL',
#                             u'http://ecx.images-amazon.com/images/I/51RZ30jFyDL._SL75_.jpg'),
#                            (u'ns2:Height',
#                             OrderedDict([(u'@Units', u'pixels'),
#                                          ('#text', u'75')])),
#                            (u'ns2:Width',
#                             OrderedDict([(u'@Units', u'pixels'),
#                                          ('#text', u'46')]))])),
#              (u'ns2:Studio', u'Bantam Spectra Books'),
#              (u'ns2:Title', u'Foundation')])

# %%
image_source = traverse(attributes, 'ns2:SmallImage/ns2:URL')
resized = re.sub('\._.*\.jpg','._SX331_BO1,204,203,200_.jpg',image_source)

# %%
raw[0]
# Out:
# OrderedDict([(u'Identifiers',
#               OrderedDict([(u'MarketplaceASIN',
#                             OrderedDict([(u'MarketplaceId', u'ATVPDKIKX0DER'),
#                                          (u'ASIN', u'0553293354')]))])),
#              (u'AttributeSets',
#               OrderedDict([(u'ns2:ItemAttributes',
#                             OrderedDict([(u'@xml:lang', u'en-US'),
#                                          (u'ns2:Author', u'Asimov, Isaac'),
#                                          (u'ns2:Binding',
#                                           u'Mass Market Paperback'),
#                                          (u'ns2:Brand', u'Spectra'),
#                                          (u'ns2:Edition', u'Revised'),
#                                          (u'ns2:Feature',
#                                           u'Used Book in Good Condition'),
#                                          (u'ns2:ItemDimensions',
#                                           OrderedDict([(u'ns2:Height',
#                                                         OrderedDict([(u'@Units',
#                                                                       u'inches'),
#                                                                      ('#text',
#                                                                       u'6.88')])),
#                                                        (u'ns2:Length',
#                                                         OrderedDict([(u'@Units',
#                                                                       u'inches'),
#                                                                      ('#text',
#                                                                       u'4.17')])),
#                                                        (u'ns2:Width',
#                                                         OrderedDict([(u'@Units',
#                                                                       u'inches'),
#                                                                      ('#text',
#                                                                       u'0.87')]))])),
#                                          (u'ns2:Label',
#                                           u'Bantam Spectra Books'),
#                                          (u'ns2:Languages',
#                                           OrderedDict([(u'ns2:Language',
#                                                         [OrderedDict([(u'ns2:Name',
#                                                                        u'english'),
#                                                                       (u'ns2:Type',
#                                                                        u'Published')]),
#                                                          OrderedDict([(u'ns2:Name',
#                                                                        u'english'),
#                                                                       (u'ns2:Type',
#                                                                        u'Original Language')]),
#                                                          OrderedDict([(u'ns2:Name',
#                                                                        u'english'),
#                                                                       (u'ns2:Type',
#                                                                        u'Unknown')])])])),
#                                          (u'ns2:ListPrice',
#                                           OrderedDict([(u'ns2:Amount',
#                                                         u'7.99'),
#                                                        (u'ns2:CurrencyCode',
#                                                         u'USD')])),
#                                          (u'ns2:Manufacturer',
#                                           u'Bantam Spectra Books'),
#                                          (u'ns2:NumberOfItems', u'1'),
#                                          (u'ns2:NumberOfPages', u'296'),
#                                          (u'ns2:PackageDimensions',
#                                           OrderedDict([(u'ns2:Height',
#                                                         OrderedDict([(u'@Units',
#                                                                       u'inches'),
#                                                                      ('#text',
#                                                                       u'1.00')])),
#                                                        (u'ns2:Length',
#                                                         OrderedDict([(u'@Units',
#                                                                       u'inches'),
#                                                                      ('#text',
#                                                                       u'6.80')])),
#                                                        (u'ns2:Width',
#                                                         OrderedDict([(u'@Units',
#                                                                       u'inches'),
#                                                                      ('#text',
#                                                                       u'4.10')])),
#                                                        (u'ns2:Weight',
#                                                         OrderedDict([(u'@Units',
#                                                                       u'pounds'),
#                                                                      ('#text',
#                                                                       u'0.20')]))])),
#                                          (u'ns2:PackageQuantity', u'1'),
#                                          (u'ns2:ProductGroup', u'Book'),
#                                          (u'ns2:ProductTypeName',
#                                           u'ABIS_BOOK'),
#                                          (u'ns2:PublicationDate',
#                                           u'1991-10-01'),
#                                          (u'ns2:Publisher',
#                                           u'Bantam Spectra Books'),
#                                          (u'ns2:ReleaseDate', u'1991-10-01'),
#                                          (u'ns2:SmallImage',
#                                           OrderedDict([(u'ns2:URL',
#                                                         u'http://ecx.images-amazon.com/images/I/51RZ30jFyDL._SL75_.jpg'),
#                                                        (u'ns2:Height',
#                                                         OrderedDict([(u'@Units',
#                                                                       u'pixels'),
#                                                                      ('#text',
#                                                                       u'75')])),
#                                                        (u'ns2:Width',
#                                                         OrderedDict([(u'@Units',
#                                                                       u'pixels'),
#                                                                      ('#text',
#                                                                       u'46')]))])),
#                                          (u'ns2:Studio',
#                                           u'Bantam Spectra Books'),
#                                          (u'ns2:Title', u'Foundation')]))])),
#              (u'Relationships', None),
#              (u'SalesRankings',
#               OrderedDict([(u'SalesRank',
#                             [OrderedDict([(u'ProductCategoryId',
#                                            u'book_display_on_website'),
#                                           (u'Rank', u'8045')]),
#                              OrderedDict([(u'ProductCategoryId', u'16286'),
#                                           (u'Rank', u'150')])])]))])

# %%
found = ProductFundamentals().fetch(clrs)

# %%
result = found[0]

# %%
result
# Out:
# {'asin': u'0262033844',
#  'authors': array([u'Cormen, Thomas H.', u'Leiserson, Charles E.',
#         u'Rivest, Ronald L.', u'Stein, Clifford'],
#        dtype='<U21'),
#  'binding': u'Hardcover',
#  'edition': u'3rd',
#  'height': u'9.00 inches',
#  'language': u'english',
#  'length': u'8.00 inches',
#  'list_price': u'99.00',
#  'pages': u'1312',
#  'published': u'2009-07-31',
#  'publisher': u'The MIT Press',
#  'released': '',
#  'sales_rank': [OrderedDict([(u'ProductCategoryId',
#                 u'book_display_on_website'),
#                (u'Rank', u'3812')]),
#   OrderedDict([(u'ProductCategoryId', u'491298'), (u'Rank', u'1')]),
#   OrderedDict([(u'ProductCategoryId', u'132570011'), (u'Rank', u'2')]),
#   OrderedDict([(u'ProductCategoryId', u'3508'), (u'Rank', u'17')])],
#  'title': u'Introduction to Algorithms, 3rd Edition (MIT Press)',
#  'weight': u'4.85 pounds',
#  'width': u'1.75 inches'}

# %%
author_str = result.get('authors')[0]

# %%
parse_authors('')
# Out:
# [{u'first': u'',
#   u'last': u'',
#   u'middle': u'',
#   u'nickname': u'',
#   u'suffix': u'',
#   u'title': u''}]

# %%
used = lowest_priced_offers.fetch('0765382032', 'used')

# %%
len('B00DS93V7Y')
# Out:
# 10

# %%
used
# Out:
# {'offers': [OrderedDict([(u'SubCondition', u'good'),
#                (u'IsFulfilledByAmazon', u'false'),
#                (u'IsBuyBoxWinner', u'false'),
#                (u'IsFeaturedMerchant', u'true'),
#                ('SellerFeedbackRating', u'98.0'),
#                ('FeedbackCount', u'176316'),
#                ('Price', u'6.21'),
#                ('ShippingPrice', u'3.99'),
#                ('ShippingMinimumHours', u'24'),
#                ('ShippingMaximumHours', u'48'),
#                ('ShippingAvailability', u'NOW'),
#                ('ShipsFromCountry', u'US'),
#                ('ShipsFromState', u'WA')]),
#   OrderedDict([(u'SubCondition', u'acceptable'),
#                (u'IsFulfilledByAmazon', u'false'),
#                (u'IsBuyBoxWinner', u'false'),
#                (u'IsFeaturedMerchant', u'true'),
#                ('SellerFeedbackRating', u'97.0'),
#                ('FeedbackCount', u'190599'),
#                ('Price', u'6.52'),
#                ('ShippingPrice', u'3.99'),
#                ('ShippingMinimumHours', u'24'),
#                ('ShippingMaximumHours', u'48'),
#                ('ShippingAvailability', u'NOW'),
#                ('ShipsFromCountry', u'US'),
#                ('ShipsFromState', u'IN')]),
#   OrderedDict([(u'SubCondition', u'acceptable'),
#                (u'IsFulfilledByAmazon', u'false'),
#                (u'IsBuyBoxWinner', u'false'),
#                (u'IsFeaturedMerchant', u'false'),
#                ('SellerFeedbackRating', u'89.0'),
#                ('FeedbackCount', u'445199'),
#                ('Price', u'7.24'),
#                ('ShippingPrice', u'3.99'),
#                ('ShippingMinimumHours', u'24'),
#                ('ShippingMaximumHours', u'48'),
#                ('ShippingAvailability', u'NOW'),
#                ('ShipsFromCountry', ''),
#                ('ShipsFromState', '')]),
#   OrderedDict([(u'SubCondition', u'acceptable'),
#                (u'IsFulfilledByAmazon', u'false'),
#                (u'IsBuyBoxWinner', u'false'),
#                (u'IsFeaturedMerchant', u'true'),
#                ('SellerFeedbackRating', u'100.0'),
#                ('FeedbackCount', u'1357'),
#                ('Price', u'7.25'),
#                ('ShippingPrice', u'3.99'),
#                ('ShippingMinimumHours', u'24'),
#                ('ShippingMaximumHours', u'48'),
#                ('ShippingAvailability', u'NOW'),
#                ('ShipsFromCountry', u'US'),
#                ('ShipsFromState', u'OR')]),
#   OrderedDict([(u'SubCondition', u'good'),
#                (u'IsFulfilledByAmazon', u'false'),
#                (u'IsBuyBoxWinner', u'false'),
#                (u'IsFeaturedMerchant', u'false'),
#                ('SellerFeedbackRating', u'96.0'),
#                ('FeedbackCount', u'751717'),
#                ('Price', u'7.97'),
#                ('ShippingPrice', u'3.99'),
#                ('ShippingMinimumHours', u'24'),
#                ('ShippingMaximumHours', u'48'),
#                ('ShippingAvailability', u'NOW'),
#                ('ShipsFromCountry', ''),
#                ('ShipsFromState', '')]),
#   OrderedDict([(u'SubCondition', u'good'),
#                (u'IsFulfilledByAmazon', u'false'),
#                (u'IsBuyBoxWinner', u'false'),
#                (u'IsFeaturedMerchant', u'true'),
#                ('SellerFeedbackRating', u'98.0'),
#                ('FeedbackCount', u'1035'),
#                ('Price', u'7.99'),
#                ('ShippingPrice', u'3.99'),
#                ('ShippingMinimumHours', u'24'),
#                ('ShippingMaximumHours', u'48'),
#                ('ShippingAvailability', u'NOW'),
#                ('ShipsFromCountry', u'US'),
#                ('ShipsFromState', u'TX')]),
#   OrderedDict([(u'SubCondition', u'good'),
#                (u'IsFulfilledByAmazon', u'false'),
#                (u'IsBuyBoxWinner', u'false'),
#                (u'IsFeaturedMerchant', u'true'),
#                ('SellerFeedbackRating', u'100.0'),
#                ('FeedbackCount', u'2604'),
#                ('Price', u'7.99'),
#                ('ShippingPrice', u'3.99'),
#                ('ShippingMinimumHours', u'24'),
#                ('ShippingMaximumHours', u'48'),
#                ('ShippingAvailability', u'NOW'),
#                ('ShipsFromCountry', u'US'),
#                ('ShipsFromState', u'KS')]),
#   OrderedDict([(u'SubCondition', u'good'),
#                (u'IsFulfilledByAmazon', u'false'),
#                (u'IsBuyBoxWinner', u'false'),
#                (u'IsFeaturedMerchant', u'true'),
#                ('SellerFeedbackRating', u'98.0'),
#                ('FeedbackCount', u'2747'),
#                ('Price', u'7.99'),
#                ('ShippingPrice', u'3.99'),
#                ('ShippingMinimumHours', u'24'),
#                ('ShippingMaximumHours', u'48'),
#                ('ShippingAvailability', u'NOW'),
#                ('ShipsFromCountry', u'US'),
#                ('ShipsFromState', u'MO')]),
#   OrderedDict([(u'SubCondition', u'acceptable'),
#                (u'IsFulfilledByAmazon', u'false'),
#                (u'IsBuyBoxWinner', u'false'),
#                (u'IsFeaturedMerchant', u'true'),
#                ('SellerFeedbackRating', u'98.0'),
#                ('FeedbackCount', u'300851'),
#                ('Price', u'8.27'),
#                ('ShippingPrice', u'3.99'),
#                ('ShippingMinimumHours', u'24'),
#                ('ShippingMaximumHours', u'48'),
#                ('ShippingAvailability', u'NOW'),
#                ('ShipsFromCountry', u'US'),
#                ('ShipsFromState', u'OR')]),
#   OrderedDict([(u'SubCondition', u'good'),
#                (u'IsFulfilledByAmazon', u'true'),
#                (u'IsBuyBoxWinner', u'false'),
#                (u'IsFeaturedMerchant', u'true'),
#                ('SellerFeedbackRating', u'100.0'),
#                ('FeedbackCount', u'471'),
#                ('Price', u'12.70'),
#                ('ShippingPrice', u'0.00'),
#                ('ShippingMinimumHours', u'0'),
#                ('ShippingMaximumHours', u'0'),
#                ('ShippingAvailability', u'NOW'),
#                ('ShipsFromCountry', ''),
#                ('ShipsFromState', '')]),
#   OrderedDict([(u'SubCondition', u'like_new'),
#                (u'IsFulfilledByAmazon', u'false'),
#                (u'IsBuyBoxWinner', u'false'),
#                (u'IsFeaturedMerchant', u'false'),
#                ('SellerFeedbackRating', u'94.0'),
#                ('FeedbackCount', u'699912'),
#                ('Price', u'8.91'),
#                ('ShippingPrice', u'3.99'),
#                ('ShippingMinimumHours', u'24'),
#                ('ShippingMaximumHours', u'48'),
#                ('ShippingAvailability', u'NOW'),
#                ('ShipsFromCountry', u'US'),
#                ('ShipsFromState', u'FL')]),
#   OrderedDict([(u'SubCondition', u'like_new'),
#                (u'IsFulfilledByAmazon', u'false'),
#                (u'IsBuyBoxWinner', u'false'),
#                (u'IsFeaturedMerchant', u'false'),
#                ('SellerFeedbackRating', u'91.0'),
#                ('FeedbackCount', u'196746'),
#                ('Price', u'8.94'),
#                ('ShippingPrice', u'3.99'),
#                ('ShippingMinimumHours', u'24'),
#                ('ShippingMaximumHours', u'48'),
#                ('ShippingAvailability', u'NOW'),
#                ('ShipsFromCountry', u'US'),
#                ('ShipsFromState', u'NJ')]),
#   OrderedDict([(u'SubCondition', u'very_good'),
#                (u'IsFulfilledByAmazon', u'false'),
#                (u'IsBuyBoxWinner', u'false'),
#                (u'IsFeaturedMerchant', u'false'),
#                ('SellerFeedbackRating', u'93.0'),
#                ('FeedbackCount', u'30'),
#                ('Price', u'8.95'),
#                ('ShippingPrice', u'3.99'),
#                ('ShippingMinimumHours', u'24'),
#                ('ShippingMaximumHours', u'48'),
#                ('ShippingAvailability', u'NOW'),
#                ('ShipsFromCountry', u'US'),
#                ('ShipsFromState', u'TX')]),
#   OrderedDict([(u'SubCondition', u'like_new'),
#                (u'IsFulfilledByAmazon', u'false'),
#                (u'IsBuyBoxWinner', u'false'),
#                (u'IsFeaturedMerchant', u'false'),
#                ('SellerFeedbackRating', u'92.0'),
#                ('FeedbackCount', u'42507'),
#                ('Price', u'9.12'),
#                ('ShippingPrice', u'3.99'),
#                ('ShippingMinimumHours', u'24'),
#                ('ShippingMaximumHours', u'48'),
#                ('ShippingAvailability', u'NOW'),
#                ('ShipsFromCountry', u'US'),
#                ('ShipsFromState', u'VA')]),
#   OrderedDict([(u'SubCondition', u'like_new'),
#                (u'IsFulfilledByAmazon', u'false'),
#                (u'IsBuyBoxWinner', u'false'),
#                (u'IsFeaturedMerchant', u'false'),
#                ('SellerFeedbackRating', u'99.0'),
#                ('FeedbackCount', u'72424'),
#                ('Price', u'9.13'),
#                ('ShippingPrice', u'3.99'),
#                ('ShippingMinimumHours', u'24'),
#                ('ShippingMaximumHours', u'48'),
#                ('ShippingAvailability', u'NOW'),
#                ('ShipsFromCountry', u'US'),
#                ('ShipsFromState', u'GA')]),
#   OrderedDict([(u'SubCondition', u'very_good'),
#                (u'IsFulfilledByAmazon', u'false'),
#                (u'IsBuyBoxWinner', u'false'),
#                (u'IsFeaturedMerchant', u'true'),
#                ('SellerFeedbackRating', u'97.0'),
#                ('FeedbackCount', u'405383'),
#                ('Price', u'10.95'),
#                ('ShippingPrice', u'3.99'),
#                ('ShippingMinimumHours', u'24'),
#                ('ShippingMaximumHours', u'48'),
#                ('ShippingAvailability', u'NOW'),
#                ('ShipsFromCountry', u'US'),
#                ('ShipsFromState', u'OR')]),
#   OrderedDict([(u'SubCondition', u'like_new'),
#                (u'IsFulfilledByAmazon', u'false'),
#                (u'IsBuyBoxWinner', u'false'),
#                (u'IsFeaturedMerchant', u'true'),
#                ('SellerFeedbackRating', u'99.0'),
#                ('FeedbackCount', u'9063'),
#                ('Price', u'11.19'),
#                ('ShippingPrice', u'3.99'),
#                ('ShippingMinimumHours', u'24'),
#                ('ShippingMaximumHours', u'48'),
#                ('ShippingAvailability', u'NOW'),
#                ('ShipsFromCountry', u'US'),
#                ('ShipsFromState', u'TN')]),
#   OrderedDict([(u'SubCondition', u'like_new'),
#                (u'IsFulfilledByAmazon', u'false'),
#                (u'IsBuyBoxWinner', u'false'),
#                (u'IsFeaturedMerchant', u'false'),
#                ('SellerFeedbackRating', u'88.0'),
#                ('FeedbackCount', u'107'),
#                ('Price', u'11.47'),
#                ('ShippingPrice', u'3.99'),
#                ('ShippingMinimumHours', u'24'),
#                ('ShippingMaximumHours', u'48'),
#                ('ShippingAvailability', u'NOW'),
#                ('ShipsFromCountry', u'US'),
#                ('ShipsFromState', u'CA')]),
#   OrderedDict([(u'SubCondition', u'like_new'),
#                (u'IsFulfilledByAmazon', u'false'),
#                (u'IsBuyBoxWinner', u'false'),
#                (u'IsFeaturedMerchant', u'false'),
#                ('SellerFeedbackRating', u'100.0'),
#                ('FeedbackCount', u'8'),
#                ('Price', u'12.00'),
#                ('ShippingPrice', u'3.99'),
#                ('ShippingMinimumHours', u'24'),
#                ('ShippingMaximumHours', u'48'),
#                ('ShippingAvailability', u'NOW'),
#                ('ShipsFromCountry', u'US'),
#                ('ShipsFromState', u'CO')]),
#   OrderedDict([(u'SubCondition', u'like_new'),
#                (u'IsFulfilledByAmazon', u'false'),
#                (u'IsBuyBoxWinner', u'false'),
#                (u'IsFeaturedMerchant', u'false'),
#                ('SellerFeedbackRating', u'88.0'),
#                ('FeedbackCount', u'14217'),
#                ('Price', u'12.53'),
#                ('ShippingPrice', u'3.99'),
#                ('ShippingMinimumHours', u'24'),
#                ('ShippingMaximumHours', u'48'),
#                ('ShippingAvailability', u'NOW'),
#                ('ShipsFromCountry', u'US'),
#                ('ShipsFromState', u'CA')])],
#  'summary': {'buybox_eligible_offers': [{'Condition': u'used',
#     'FulfillmentChannel': u'Merchant',
#     'NumberOfOffers': u'11'},
#    {'Condition': u'new',
#     'FulfillmentChannel': u'Amazon',
#     'NumberOfOffers': u'3'},
#    {'Condition': u'used',
#     'FulfillmentChannel': u'Amazon',
#     'NumberOfOffers': u'2'},
#    {'Condition': u'new',
#     'FulfillmentChannel': u'Merchant',
#     'NumberOfOffers': u'29'}],
#   'buybox_prices': [{'Condition': u'New',
#     u'LandedPrice': u'10.39',
#     u'ListingPrice': u'10.39',
#     u'Shipping': u'0.00'},
#    {'Condition': u'Used',
#     u'LandedPrice': u'17.68',
#     u'ListingPrice': u'12.70',
#     u'Shipping': u'4.98'}],
#   'list_price': u'15.99',
#   'lowest_prices': [{'Condition': u'used',
#     'FulfillmentChannel': u'Merchant',
#     u'LandedPrice': u'10.20',
#     u'ListingPrice': u'6.21',
#     u'Shipping': u'3.99'},
#    {'Condition': u'new',
#     'FulfillmentChannel': u'Amazon',
#     u'LandedPrice': u'10.39',
#     u'ListingPrice': u'10.39',
#     u'Shipping': u'0.00'},
#    {'Condition': u'used',
#     'FulfillmentChannel': u'Amazon',
#     u'LandedPrice': u'12.70',
#     u'ListingPrice': u'12.70',
#     u'Shipping': u'0.00'},
#    {'Condition': u'new',
#     'FulfillmentChannel': u'Merchant',
#     u'LandedPrice': u'10.31',
#     u'ListingPrice': u'6.32',
#     u'Shipping': u'3.99'}],
#   'number_of_offers': [{'Condition': u'used',
#     'FulfillmentChannel': u'Merchant',
#     'NumberOfOffers': u'26'},
#    {'Condition': u'new',
#     'FulfillmentChannel': u'Amazon',
#     'NumberOfOffers': u'3'},
#    {'Condition': u'used',
#     'FulfillmentChannel': u'Amazon',
#     'NumberOfOffers': u'2'},
#    {'Condition': u'new',
#     'FulfillmentChannel': u'Merchant',
#     'NumberOfOffers': u'59'}],
#   'total_offer_count': u'90'}}

# %%
used_offers = used['offers']

# %%
summary = used['summary']

# %%
summary.keys()
# Out:
# ['total_offer_count',
#  'list_price',
#  'number_of_offers',
#  'buybox_eligible_offers',
#  'buybox_prices',
#  'lowest_prices']

# %%
pd.DataFrame(summary['buybox_prices'])
# Out:
#   Condition LandedPrice ListingPrice Shipping
# 0       New       10.39        10.39     0.00
# 1      Used       17.68        12.70     4.98

# %%
r = lowest_priced_offers.get(gott, 'new')

# %%
new = lowest_priced_offers.read(r, raw=True)

# %%
summary = new['summary']

# %%
list(summary)
# Out:
# [u'TotalOfferCount',
#  u'NumberOfOffers',
#  u'LowestPrices',
#  u'BuyBoxPrices',
#  u'ListPrice',
#  u'BuyBoxEligibleOffers']

# %%
summary
# Out:
# OrderedDict([(u'TotalOfferCount', u'191'),
#              (u'NumberOfOffers',
#               OrderedDict([(u'OfferCount',
#                             [OrderedDict([(u'@condition', u'used'),
#                                           (u'@fulfillmentChannel',
#                                            u'Merchant'),
#                                           ('#text', u'73')]),
#                              OrderedDict([(u'@condition', u'new'),
#                                           (u'@fulfillmentChannel', u'Amazon'),
#                                           ('#text', u'2')]),
#                              OrderedDict([(u'@condition', u'used'),
#                                           (u'@fulfillmentChannel', u'Amazon'),
#                                           ('#text', u'8')]),
#                              OrderedDict([(u'@condition', u'new'),
#                                           (u'@fulfillmentChannel',
#                                            u'Merchant'),
#                                           ('#text', u'108')])])])),
#              (u'LowestPrices',
#               OrderedDict([(u'LowestPrice',
#                             [OrderedDict([(u'@condition', u'used'),
#                                           (u'@fulfillmentChannel',
#                                            u'Merchant'),
#                                           (u'LandedPrice',
#                                            OrderedDict([(u'CurrencyCode',
#                                                          u'USD'),
#                                                         (u'Amount',
#                                                          u'8.95')])),
#                                           (u'ListingPrice',
#                                            OrderedDict([(u'CurrencyCode',
#                                                          u'USD'),
#                                                         (u'Amount',
#                                                          u'4.96')])),
#                                           (u'Shipping',
#                                            OrderedDict([(u'CurrencyCode',
#                                                          u'USD'),
#                                                         (u'Amount',
#                                                          u'3.99')]))]),
#                              OrderedDict([(u'@condition', u'new'),
#                                           (u'@fulfillmentChannel', u'Amazon'),
#                                           (u'LandedPrice',
#                                            OrderedDict([(u'CurrencyCode',
#                                                          u'USD'),
#                                                         (u'Amount',
#                                                          u'9.60')])),
#                                           (u'ListingPrice',
#                                            OrderedDict([(u'CurrencyCode',
#                                                          u'USD'),
#                                                         (u'Amount',
#                                                          u'9.60')])),
#                                           (u'Shipping',
#                                            OrderedDict([(u'CurrencyCode',
#                                                          u'USD'),
#                                                         (u'Amount',
#                                                          u'0.00')]))]),
#                              OrderedDict([(u'@condition', u'used'),
#                                           (u'@fulfillmentChannel', u'Amazon'),
#                                           (u'LandedPrice',
#                                            OrderedDict([(u'CurrencyCode',
#                                                          u'USD'),
#                                                         (u'Amount',
#                                                          u'12.00')])),
#                                           (u'ListingPrice',
#                                            OrderedDict([(u'CurrencyCode',
#                                                          u'USD'),
#                                                         (u'Amount',
#                                                          u'12.00')])),
#                                           (u'Shipping',
#                                            OrderedDict([(u'CurrencyCode',
#                                                          u'USD'),
#                                                         (u'Amount',
#                                                          u'0.00')]))]),
#                              OrderedDict([(u'@condition', u'new'),
#                                           (u'@fulfillmentChannel',
#                                            u'Merchant'),
#                                           (u'LandedPrice',
#                                            OrderedDict([(u'CurrencyCode',
#                                                          u'USD'),
#                                                         (u'Amount',
#                                                          u'6.99')])),
#                                           (u'ListingPrice',
#                                            OrderedDict([(u'CurrencyCode',
#                                                          u'USD'),
#                                                         (u'Amount',
#                                                          u'3.00')])),
#                                           (u'Shipping',
#                                            OrderedDict([(u'CurrencyCode',
#                                                          u'USD'),
#                                                         (u'Amount',
#                                                          u'3.99')]))])])])),
#              (u'BuyBoxPrices',
#               OrderedDict([(u'BuyBoxPrice',
#                             [OrderedDict([(u'@condition', u'New'),
#                                           (u'LandedPrice',
#                                            OrderedDict([(u'CurrencyCode',
#                                                          u'USD'),
#                                                         (u'Amount',
#                                                          u'9.60')])),
#                                           (u'ListingPrice',
#                                            OrderedDict([(u'CurrencyCode',
#                                                          u'USD'),
#                                                         (u'Amount',
#                                                          u'9.60')])),
#                                           (u'Shipping',
#                                            OrderedDict([(u'CurrencyCode',
#                                                          u'USD'),
#                                                         (u'Amount',
#                                                          u'0.00')]))]),
#                              OrderedDict([(u'@condition', u'Used'),
#                                           (u'LandedPrice',
#                                            OrderedDict([(u'CurrencyCode',
#                                                          u'USD'),
#                                                         (u'Amount',
#                                                          u'16.98')])),
#                                           (u'ListingPrice',
#                                            OrderedDict([(u'CurrencyCode',
#                                                          u'USD'),
#                                                         (u'Amount',
#                                                          u'12.00')])),
#                                           (u'Shipping',
#                                            OrderedDict([(u'CurrencyCode',
#                                                          u'USD'),
#                                                         (u'Amount',
#                                                          u'4.98')]))])])])),
#              (u'ListPrice',
#               OrderedDict([(u'CurrencyCode', u'USD'), (u'Amount', u'16.00')])),
#              (u'BuyBoxEligibleOffers',
#               OrderedDict([(u'OfferCount',
#                             [OrderedDict([(u'@condition', u'used'),
#                                           (u'@fulfillmentChannel',
#                                            u'Merchant'),
#                                           ('#text', u'36')]),
#                              OrderedDict([(u'@condition', u'new'),
#                                           (u'@fulfillmentChannel', u'Amazon'),
#                                           ('#text', u'2')]),
#                              OrderedDict([(u'@condition', u'used'),
#                                           (u'@fulfillmentChannel', u'Amazon'),
#                                           ('#text', u'6')]),
#                              OrderedDict([(u'@condition', u'new'),
#                                           (u'@fulfillmentChannel',
#                                            u'Merchant'),
#                                           ('#text', u'41')])])]))])

# %%
gott
# Out:
# '1594634025'

# %%
funds[1]
# Out:
# {'authors': array([u'Charles E. Leiserson'],
#        dtype='<U20'),
#  'binding': u'Paperback',
#  'edition': u'Cincias Exatas',
#  'height': '',
#  'language': u'english',
#  'last_status': u'Success',
#  'length': '',
#  'list_price': '',
#  'page_count': '',
#  'published': u'2009-01-01',
#  'publisher': u'THE MIT PRESS',
#  'released': '',
#  'sales_rank': '',
#  'title': u'Introduction To Algorithms',
#  'weight': '',
#  'width': ''}

# %%
pd.DataFrame(summary['lowest_prices'])
# Out:
#   Condition FulfillmentChannel LandedPrice ListingPrice Shipping
# 0      used           Merchant        8.95         4.96     3.99
# 1       new             Amazon        9.60         9.60     0.00
# 2      used             Amazon       12.00        12.00     0.00
# 3       new           Merchant        6.99         3.00     3.99

# %%
offers = pd.DataFrame(new['offers'])

# %%
response = product_fundamentals.get(clrs)

# %%
xml = product_fundamentals.read(response, raw=True)

# %%
[traverse(p, 'Identifiers/MarketplaceASIN/ASIN') for p in xml]
# Out:
# [u'0262033844',
#  u'B007YXXTRM',
#  u'B00JP72CZK',
#  u'B00KYS1JDK',
#  u'B00LA14KWC',
#  u'B00LLHEESK',
#  u'B007CNRCAO']

# %%
funds = product_fundamentals.fetch(gott)

# %%
from pprint import pprint

# %%
pprint(funds)
# Out:
# [{'asin': u'1594634025',
#   'authors': array([u'Hawkins, Paula'],
#       dtype='<U14'),
#   'binding': u'Paperback',
#   'edition': u'Reprint',
#   'height': u'8.00 inches',
#   'language': u'english',
#   'last_status': u'Success',
#   'length': u'5.10 inches',
#   'list_price': u'16.00',
#   'page_count': u'336',
#   'published': u'2016-07-12',
#   'publisher': u'Riverhead Books',
#   'released': u'2016-07-12',
#   'sales_rank': [OrderedDict([(u'ProductCategoryId', u'book_display_on_website'), (u'Rank', u'4')]),
#                  OrderedDict([(u'ProductCategoryId', u'10132'), (u'Rank', u'11')]),
#                  OrderedDict([(u'ProductCategoryId', u'13354'), (u'Rank', u'12')]),
#                  OrderedDict([(u'ProductCategoryId', u'10495'), (u'Rank', u'17')])],
#   'title': u'The Girl on the Train',
#   'weight': u'1.00 pounds',
#   'width': u'0.80 inches'}]

# %%
offers
# Out:
#    FeedbackCount IsBuyBoxWinner IsFeaturedMerchant IsFulfilledByAmazon Price  \
# 0              0          false              false               false  3.00
# 1              2          false              false               false  3.90
# 2             56          false              false               false  5.01
# 3            176          false              false               false  5.60
# 4            387           true               true                true  9.60
# 5         176408          false               true               false  5.99
# 6              7          false              false               false  6.00
# 7           3484          false              false               false  6.79
# 8            122          false              false               false  6.80
# 9          87557          false               true               false  7.15
# 10         14091          false               true               false  7.20
# 11        100156          false              false               false  7.35
# 12         47754          false               true               false  7.69
# 13            15          false              false               false  8.00
# 14             8          false              false               false  8.00
# 15             0          false              false               false  8.22
# 16        163830          false              false               false  8.75
# 17             0          false              false               false  9.00
# 18        445187          false              false               false  9.27
# 19        751687          false              false               false  9.28
#
#    SellerFeedbackRating ShippingAvailability ShippingMaximumHours  \
# 0                   0.0                  NOW                   48
# 1                  50.0                  NOW                   48
# 2                 100.0                  NOW                   48
# 3                  98.0                  NOW                   48
# 4                  91.0                  NOW                    0
# 5                  97.0                  NOW                   48
# 6                 100.0                  NOW                   48
# 7                 100.0                  NOW                   48
# 8                  89.0                  NOW                   48
# 9                 100.0                  NOW                   48
# 10                 98.0                  NOW                   48
# 11                 88.0                  NOW                   48
# 12                 99.0                  NOW                   48
# 13                100.0                  NOW                   48
# 14                 88.0                  NOW                   48
# 15                  0.0                  NOW                   48
# 16                 89.0                  NOW                   48
# 17                  0.0                  NOW                   48
# 18                 89.0                  NOW                   48
# 19                 96.0                  NOW                   48
#
#    ShippingMinimumHours ShippingPrice ShipsFromCountry ShipsFromState  \
# 0                    24          3.99               US             NY
# 1                    24          3.99               US             IL
# 2                    24          3.99
# 3                    24          3.99
# 4                     0          0.00
# 5                    24          3.99               US             NY
# 6                    24          3.99               US             NC
# 7                    24          3.99
# 8                    24          3.99               US             NJ
# 9                    24          3.99               US             TN
# 10                   24          3.99
# 11                   24          3.99
# 12                   24          3.99
# 13                   24          3.99               US             VA
# 14                   24          3.99
# 15                   24          3.99               US             WA
# 16                   24          3.99
# 17                   24          3.99               US             CT
# 18                   24          3.99
# 19                   24          3.99
#
#    SubCondition
# 0           new
# 1           new
# 2           new
# 3           new
# 4           new
# 5           new
# 6           new
# 7           new
# 8           new
# 9           new
# 10          new
# 11          new
# 12          new
# 13          new
# 14          new
# 15          new
# 16          new
# 17          new
# 18          new
# 19          new

# %%
funds = product_fundamentals.fetch(clrs)

# %%
funds[0]
# Out:
# {'asin': u'0262033844',
#  'authors': array([u'Cormen, Thomas H.', u'Leiserson, Charles E.',
#         u'Rivest, Ronald L.', u'Stein, Clifford'],
#        dtype='<U21'),
#  'binding': u'Hardcover',
#  'edition': u'3rd',
#  'height': u'9.00 inches',
#  'language': u'english',
#  'last_status': u'Success',
#  'length': u'8.00 inches',
#  'list_price': u'99.00',
#  'page_count': u'1312',
#  'published': u'2009-07-31',
#  'publisher': u'The MIT Press',
#  'released': '',
#  'sales_rank': [OrderedDict([(u'ProductCategoryId',
#                 u'book_display_on_website'),
#                (u'Rank', u'6252')]),
#   OrderedDict([(u'ProductCategoryId', u'132570011'), (u'Rank', u'2')]),
#   OrderedDict([(u'ProductCategoryId', u'491298'), (u'Rank', u'3')]),
#   OrderedDict([(u'ProductCategoryId', u'3508'), (u'Rank', u'32')])],
#  'title': u'Introduction to Algorithms, 3rd Edition (MIT Press)',
#  'weight': u'4.85 pounds',
#  'width': u'1.75 inches'}

# %%
[fund['binding'] for fund in funds]
# Out:
# [u'Hardcover',
#  u'Paperback',
#  u'Kindle Edition',
#  u'Kindle Edition',
#  u'Kindle Edition',
#  u'Kindle Edition',
#  u'Kindle Edition']

# %%
offers[['SubCondition','Price','ShippingPrice']]
# Out:
#    SubCondition Price ShippingPrice
# 0           new  3.00          3.99
# 1           new  3.90          3.99
# 2           new  5.01          3.99
# 3           new  5.60          3.99
# 4           new  9.60          0.00
# 5           new  5.99          3.99
# 6           new  6.00          3.99
# 7           new  6.79          3.99
# 8           new  6.80          3.99
# 9           new  7.15          3.99
# 10          new  7.20          3.99
# 11          new  7.35          3.99
# 12          new  7.69          3.99
# 13          new  8.00          3.99
# 14          new  8.00          3.99
# 15          new  8.22          3.99
# 16          new  8.75          3.99
# 17          new  9.00          3.99
# 18          new  9.27          3.99
# 19          new  9.28          3.99

# %%
tb = lowest_priced_offers.fetch(three_body, 'new')

# %%
pd.DataFrame(tb['offers'])
# Out:
#    FeedbackCount IsBuyBoxWinner IsFeaturedMerchant IsFulfilledByAmazon  Price  \
# 0         100158          false              false               false   6.32
# 1            387           true               true                true  10.39
# 2         163836          false              false               false   6.46
# 3             37          false               true                true  11.49
# 4         751702          false              false               false   7.65
# 5          20557          false               true                true  11.66
# 6         463597          false               true               false   8.87
# 7         699909          false              false               false   8.91
# 8         196744          false              false               false   8.94
# 9          42506          false              false               false   9.12
# 10         72420          false              false               false   9.13
# 11        445190          false              false               false   9.49
# 12        322166          false               true               false   9.72
# 13         30813          false              false               false   9.73
# 14        251514          false               true               false   9.76
# 15        349361          false              false               false  10.12
# 16          9062          false               true               false  10.36
# 17        422163          false               true               false  10.50
# 18        767053          false               true               false  10.61
# 19          2762          false              false               false  10.65
#
#    SellerFeedbackRating ShippingAvailability ShippingMaximumHours  \
# 0                  88.0                  NOW                   72
# 1                  91.0                  NOW                    0
# 2                  89.0                  NOW                   72
# 3                  97.0                  NOW                    0
# 4                  96.0                  NOW                   48
# 5                  97.0                  NOW                    0
# 6                  97.0                  NOW                   48
# 7                  94.0                  NOW                   48
# 8                  91.0                  NOW                   48
# 9                  92.0                  NOW                   48
# 10                 99.0                  NOW                   48
# 11                 89.0                  NOW                   48
# 12                 97.0                  NOW                   48
# 13                 98.0                  NOW                   48
# 14                 97.0                  NOW                   48
# 15                 96.0                  NOW                   48
# 16                 99.0                  NOW                   48
# 17                 99.0                  NOW                   96
# 18                 95.0                  NOW                   48
# 19                 93.0                  NOW                   72
#
#    ShippingMinimumHours ShippingPrice ShipsFromCountry ShipsFromState  \
# 0                    48          3.99
# 1                     0          0.00
# 2                    48          3.99
# 3                     0          0.00
# 4                    24          3.99
# 5                     0          0.00
# 6                    24          3.99               US             GA
# 7                    24          3.99               US             FL
# 8                    24          3.99               US             NJ
# 9                    24          3.99               US             VA
# 10                   24          3.99               US             GA
# 11                   24          3.99
# 12                   24          3.99               US             IL
# 13                   24          3.99               US             IL
# 14                   24          3.99
# 15                   24          3.99               US             SC
# 16                   24          3.99               US             TN
# 17                   72          3.99               US             MI
# 18                   24          3.99
# 19                   48          3.99               US             GA
#
#    SubCondition
# 0           new
# 1           new
# 2           new
# 3           new
# 4           new
# 5           new
# 6           new
# 7           new
# 8           new
# 9           new
# 10          new
# 11          new
# 12          new
# 13          new
# 14          new
# 15          new
# 16          new
# 17          new
# 18          new
# 19          new

# %%
response = product_categories.get(three_body)

# %%
xml = xmltodict.parse(response.text)

# %%
trees = traverse(xml, 'GetProductCategoriesForASINResponse/GetProductCategoriesForASINResult/Self')

# %%
tree = trees[0]

# %%
tree.items()
# Out:
# [(u'ProductCategoryId', u'10397'),
#  (u'ProductCategoryName', u'Chinese'),
#  (u'Parent',
#   OrderedDict([(u'ProductCategoryId', u'271599011'),
#                (u'ProductCategoryName', u'Asian'),
#                (u'Parent',
#                 OrderedDict([(u'ProductCategoryId', u'10311'),
#                              (u'ProductCategoryName', u'World Literature'),
#                              (u'Parent',
#                               OrderedDict([(u'ProductCategoryId', u'17'),
#                                            (u'ProductCategoryName',
#                                             u'Literature & Fiction'),
#                                            (u'Parent',
#                                             OrderedDict([(u'ProductCategoryId',
#                                                           u'1000'),
#                                                          (u'ProductCategoryName',
#                                                           u'Subjects'),
#                                                          (u'Parent',
#                                                           OrderedDict([(u'ProductCategoryId',
#                                                                         u'283155'),
#                                                                        (u'ProductCategoryName',
#                                                                         u'Subjects')]))]))]))]))]))]
